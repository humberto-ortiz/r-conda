# %% [markdown]
# # Jupyter Notebooks
#
# Binder can also run jupyter notebooks. You can mix markdown text with python code chunks, like the RStudio Rmd files.

# %%
a = 2 * 2 * 5

# %%
a
# Out:
# 20
